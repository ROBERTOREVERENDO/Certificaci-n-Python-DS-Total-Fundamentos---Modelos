# %%
VARIABLES
LOCALES
GENERALES
GLOBALES

# %%
PARTE 1: PERSPECTIVA GENERAL DEL CURSO
    CADA PROBLEMA SE REALIZARÁ EN 
    DIGRAMA DE FLUJO
    PSEUDOCODIGO
    PROGRAMACIÓN DEV
    PROGRAMACION VBA
    
MANEJO DE CADENAS
    
PARTE 2: FUNDAMENTOS DE PROGRAMACION
    TIPOS DE DATOS
    ENTERO
    DECIMAL
    BOOL
    DATE
    TIME
    DATETIME
    
    AGRUPADORES
    VECTORES
    MATRICES
    
    REFERENCIA A DIRECCIÓN
    PUNTEROS
    
    DEFINICION DE UNA VARIABLE
    VARIABLES
        LOCALES
        GENERALES
        GLOBALES
    
PARTE 3: SENTENCIAS DE OPERACIÓN
    
    
PARTE 3: SENTENCIAS DE ASIGNACIÓN
    
PARTE 4: SENTENCIAS DE COMPARACION
    
PARTE 5: SENTENCIAS CONDICIONALES / SENTENCIAS SELECTIVAS
    BASICAS
    SIMPLES
    DOBLES /NIDADAS
    MULTPLES
    
AGRUPADORES
CONTADORES

    
PARTE 6: SENTENCIAS REPETITIVAS
    DONDE NO CONOZCO LA CANTIDAD DE VECES QUE SE REPITE
    
    ENTRADA CONTROLADA
    SALIDA CONTROLADA
    
    ROMPER UNA REPETITIVA POR PREGUNTA
    ROMPER UNA REPETITIVA POR CONDICION
    
    DONDE SI CONOZCO LA CANTIDAD DE VECES QUE SE REPITE
    PARA HASTA
    
ALGORITMOS MAYOR
ALGORITMOS MENOR
ALGORITMOS DE PRIMOS
ALGORITMOS DE CIFRAS
ALGORITMOS DE SERIES
ALGORITMOS DE GRAFICAS

ESTRUCTURAS DE DATOS
VECTORES
MATRICES
ESTRUCTURAS

SUBPROGRAMAS
FUNCIONES
PROCEDIMIENTOS

MPODULOS
PUNTEROS

# %%
MENCIONAR QUE ANTES DE ESTUDIAR CUALQUIER LENGUAJE O TECNOLOGIA
ES NECESARIO ENTENDER 2 COSAS
ALGORITMOS
Y CÁLCULO

TODO EN TU VIDA TIENE ALGORITMOS
DESDE CUANDO TE LEVANTAS
HASTA COMO LLEGASTE A ESTE CURSO SON ALGORITMOS

COMO ESCOGER NOMBRE DE UNA VARIABLE

COMO ESCOGER LAS SENTENCIAS DENTRO DE UNA REPETITIVA

INICIALIZAR EL MAYOR Y MENOR MEDIANTE 2 METODOS (VALOR INICIAL Y PRIMER INGRESO)

MATRIZ IDENTIDAD

FUNCIÓN GOTOXY

MANEJO DE MAYUSCULAS Y MINUSCULAS

FUNCIONES -> DIME ALGO
PROCEDIMIENTOS -> GRITA

by ref
by val

proyecto vba
