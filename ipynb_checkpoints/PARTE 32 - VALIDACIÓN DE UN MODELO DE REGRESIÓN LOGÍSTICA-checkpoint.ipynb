# %% [markdown]
# # PARTE 32: VALIDACIÓN DE UN MODELO LOGÍSTICO

# %% [markdown]
# ## PARTE 32.1: VALIDACIÓN MEDIANTE CURVA ROC

# %%
from IPython.display import Image
Image(filename="RECURSOS - CERTIFICACIÓN/CURVA_ROC.png")

# %%
from IPython.display import Image
Image(filename="RECURSOS - CERTIFICACIÓN/CURVA_ROC_2.png")

# %%
from IPython.display import Image
Image(filename="RECURSOS - CERTIFICACIÓN/CURVA_ROC_3.png")

# %% [markdown]
# #### PASO 1: IMPORTAR EL DATASET

# %% [markdown]
# #### PASO 2: DEFINIR DATASET PREDICHO Y PREDICTOR

# %% [markdown]
# #### PASO 3: NORMALIZAR EL DATASET PREDICTOR

# %% [markdown]
# #### PASO 4: GENERAR EL SELECTOR

# %% [markdown]
# #### PASO 5: DEFINIR RANKING DE VARIABLES

# %% [markdown]
# #### PASO 6: GENERAR UN MODELO LOGÍSTICO SKLEARN CON N VARIABLES

# %% [markdown]
# #### PASO 7: GENERAR UN MODELO LOGÍSTICO STATSMODEL CON N VARIABLES

# %% [markdown]
# #### PASO 8: CALCULAR LA SALIDA CON UMBRAL POR DEFECTO

# %% [markdown]
# #### PASO 11: GRAFICAR CURVA ROC (Receiver Operating Characteristic) A MANO
#
# * EJE X --> 1-ESPECIFICIDAD --> RELACIÓN DE FP
# * EJE Y --> SENSIBILIDAD --> RELACIÓN DE VP

# %% [markdown]
# ## PARTE 32.2: VALIDACIÓN HABITUAL DE MODELO LOGÍSTICO
#
# * PASO 1: DIVIDIR EL DATASET EN ENTRENAMIENTO Y PRUEBA (TANTO EL PREDICTORIO COMO EL PREDICHO)
# * PASO 2: IMPLEMENTAR EL MODELO QUE TUVO BUENOS INDICADORES CON SOLO EL DATASET DE ENTRENAMIENTO
# * PASO 3: VERIFICAR QUE AÚN TENGA BUENOS INDICADORES
# * PASO 4: PASO 4: PREDECIR SOBRE EL DATASET DE PRUEBA  Y OBTENER INDICADORES

# %% [markdown]
# #### PASO 1: DIVIDIR EL DATASET EN ENTRENAMIENTO Y PRUEBA (TANTO EL PREDICTORIO COMO EL PREDICHO)

# %% [markdown]
# #### PASO 3: VERIFICAR QUE AÚN TENGA BUENOS INDICADORES

# %% [markdown]
# #### PASO 4: PREDECIR SOBRE EL DATASET DE PRUEBA  Y OBTENER INDICADORES

# %% [markdown]
# ## PARTE 32.3: CROSS VALIDATION - VALIDACIÓN CRUZADA
#
# ### https://scikit-learn.org/stable/modules/model_evaluation.html

# %%
from IPython.display import Image
Image(filename="RECURSOS - CERTIFICACIÓN/KFOLD_CROSS_VALIDATION.jpg")
