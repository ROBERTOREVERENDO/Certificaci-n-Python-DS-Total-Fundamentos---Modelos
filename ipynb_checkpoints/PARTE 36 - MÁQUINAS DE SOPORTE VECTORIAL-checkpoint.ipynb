# %% [markdown]
# # PARTE 36: MÁQUINAS DE SOPORTE VECTORIAL

# %%
from IPython.display import Image
Image(filename="RECURSOS - CERTIFICACIÓN/MSV - Definición.png")

# %%
from IPython.display import Image
Image(filename="RECURSOS - CERTIFICACIÓN/Algoritmo óptimo de MSV.png")

# %%
from IPython.display import Image
Image(filename="RECURSOS - CERTIFICACIÓN/Algoritmo con error de MSV.png")

# %% [markdown]
# ## PARTE 36.1: FUNCIONAMIENTO DE UN VECTOR LINEAL

# %% [markdown]
# ## PARTE 36.2: GRÁFICA DE UN VECTOR LINEAL

# %%
from IPython.display import Image
Image(filename="RECURSOS - CERTIFICACIÓN/Propuestas de Vector.png")

# %% [markdown]
# ## PARTE 36.3: COMPORTAMIENTO DE UNA MSV MEDIANTE KERNEL

# %%
from IPython.display import Image
Image(filename="RECURSOS - CERTIFICACIÓN/Divisiones no Lineales.png")

# %% [markdown]
# ## PARTE 36.4: MSV PARA PROCESAR ROSTROS

# %%
#https://scikit-learn.org/stable/modules/classes.html#module-sklearn.datasets
