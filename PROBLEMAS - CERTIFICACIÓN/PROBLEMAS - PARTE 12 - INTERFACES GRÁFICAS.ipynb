# %% [markdown]
# ### PROBLEMA 1
#
# Investiga sobre el widget "POP-UP" e implementa una interfaz en la que haya 2 botones:
# * BOTÓN HOLA --> Aparece un pop-up que diga "HOLA, CÓMO ESTÁS?"
# * BOTÓN CHAU --> Aparece un pop-up que diga "CHAU, HASTA LUEGO"

# %% [markdown]
# ### PROBLEMA 2
#
# Modifica el Proyecto 1 y colócale un POP-UP que te indique 1 sola vez (al lanzar el proyecto) la cantidad de fotos que se recorrerán

# %% [markdown]
# ### PROBLEMA 3
#
# Mejora el Proyecto 1 para que recorra todas las fotos de una ruta sin tener que colocar sus nombres en el código

# %% [markdown]
# ### PROBLEMA 4
#
# Modifica el Proyecto 2 y colócale un POP-UP que muestre el mensaje "Se ha generado correctamente el resultado" cada vez que se presiona el botón IGUAL
#
# * Sé que es un tanto molesto pero es para que practiques

# %% [markdown]
# ### PROBLEMA 5
#
# Modifica el Proyecto 3 y colócale un POP-UP que muestre el mensaje acorde a la interacción que se realiza con BD

# %% [markdown]
# ### PROBLEMA 6
#
# Implementa el siguiente mini-proyecto

# %%
from IPython.display import Image
Image(filename="PROPUESTA DE PROYECTO.png")
